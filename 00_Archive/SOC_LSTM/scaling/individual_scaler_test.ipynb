# %%
import pandas as pd
import matplotlib.pyplot as plt

# Pfad zur Parquet-Datei
parquet_file_path = "/home/florianr/MG_Farm/5_Data//MGFarm_18650_Dataframes/MGFarm_18650_C23/df_scaled.parquet"

# Lese die ersten 1% der Daten
df = pd.read_parquet(parquet_file_path)
sample_size = int(len(df) * 0.01)  # 1% der Daten
df_sampled = df.head(sample_size)

df_sampled["timestamp"] = pd.to_datetime(df_sampled["Absolute_Time[yyyy-mm-dd hh:mm:ss]"])

plt.figure(figsize=(10, 6))
plt.plot(df_sampled["timestamp"], df_sampled["Scaled_Voltage[V]"], label="Scaled_Voltage[V]")
plt.plot(df_sampled["timestamp"], df_sampled["Scaled_Current[A]"], label="Scaled_Current[A]")
plt.plot(df_sampled["timestamp"], df_sampled["Scaled_Temperature[°C]"], label="Scaled_Temperature[°C]")
plt.title("Voltage, Current, Temperature Over Time (First 1%)")
plt.xlabel("Time")
plt.ylabel("Values")
plt.legend()
plt.show()

# Pfad zur Parquet-Datei
parquet_file_path = "/home/florianr/MG_Farm/5_Data//MGFarm_18650_Dataframes/MGFarm_18650_C23/df.parquet"

# Lese die ersten 1% der Daten
df = pd.read_parquet(parquet_file_path)
sample_size = int(len(df) * 0.01)  # 1% der Daten
df_sampled = df.head(sample_size)

df_sampled["timestamp"] = pd.to_datetime(df_sampled["Absolute_Time[yyyy-mm-dd hh:mm:ss]"])

plt.figure(figsize=(10, 6))
plt.plot(df_sampled["timestamp"], df_sampled["Voltage[V]"], label="Voltage[V]")
#plt.plot(df_sampled["timestamp"], df_sampled["Current[A]"], label="Current[A]")
#plt.plot(df_sampled["timestamp"], df_sampled["Temperature[°C]"], label="Temperature[°C]")
plt.title("Voltage, Current, Temperature Over Time (First 1%)")
plt.xlabel("Time")
plt.ylabel("Values")
plt.legend()
plt.show()


plt.figure(figsize=(10, 4))
plt.plot(df_sampled["timestamp"], df_sampled["SOC_ZHU"], label="SOC")
plt.title("SOC Over Time (First 1%)")
plt.xlabel("Time")
plt.ylabel("SOC")
plt.show()
# Out:
# /tmp/ipykernel_186177/440088387.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sampled["timestamp"] = pd.to_datetime(df_sampled["Absolute_Time[yyyy-mm-dd hh:mm:ss]"])
# /tmp/ipykernel_186177/440088387.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sampled["timestamp"] = pd.to_datetime(df_sampled["Absolute_Time[yyyy-mm-dd hh:mm:ss]"])
